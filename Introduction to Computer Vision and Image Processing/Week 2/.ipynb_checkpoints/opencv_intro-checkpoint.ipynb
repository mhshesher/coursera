# %%
import cv2 as cv
from matplotlib import pyplot as plt
import numpy as np

# %%
img_path='/home/mehedi/github/coursera/Introduction to Computer Vision and Image Processing/Week 2/Test_Image/'

# %%
img=cv.imread(img_path+'baboon.jpg')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (509, 339, 3)

# %%
print(img[:,:,0])
print(img[:,:,2])
# Out:
# [[11 12 10 ... 13 14 13]
#  [11 14 12 ... 12 13 12]
#  [ 9 11 11 ...  9 12 12]
#  ...
#  [25 30 36 ... 23  6 15]
#  [20 34 45 ... 24 15 11]
#  [19 41 39 ... 20 25  6]]
# [[24 23 21 ... 24 25 24]
#  [24 25 23 ... 23 24 23]
#  [22 22 22 ... 20 23 23]
#  ...
#  [40 45 54 ... 18  3 12]
#  [34 48 60 ... 17  8  8]
#  [31 55 54 ... 13 18  1]]

# %%
img2=cv.cvtColor(img,cv.COLOR_BGR2RGB)

# %%
img2.shape
# Out:
# (509, 339, 3)

# %%
print(img2[:,:,0])
print(img2[:,:,2])
# Out:
# [[24 23 21 ... 24 25 24]
#  [24 25 23 ... 23 24 23]
#  [22 22 22 ... 20 23 23]
#  ...
#  [40 45 54 ... 18  3 12]
#  [34 48 60 ... 17  8  8]
#  [31 55 54 ... 13 18  1]]
# [[11 12 10 ... 13 14 13]
#  [11 14 12 ... 12 13 12]
#  [ 9 11 11 ...  9 12 12]
#  ...
#  [25 30 36 ... 23  6 15]
#  [20 34 45 ... 24 15 11]
#  [19 41 39 ... 20 25  6]]

# %%
img[:,:,0]==img2[:,:,2]
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
plt.imshow(img2)

# %%
img_gray=cv.cvtColor(img2,cv.COLOR_RGB2GRAY)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
cv.imwrite(img_path+'baboon_gray2.jpg',img_gray)
# Out:
# True

# %%
img_gray2=cv.imread(img_path+"baboon.jpg",cv.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray2,cmap='gray')

# %%
blue,green,red=img2[:,:,0],img2[:,:,1],img2[:,:,2]

# %%
print(img2.shape)
print(red.shape)
print(green.shape)
print(blue.shape)
# Out:
# (509, 339, 3)
# (509, 339)
# (509, 339)
# (509, 339)
