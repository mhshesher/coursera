# %%
from PIL import Image
from matplotlib import pyplot as plt
from PIL import ImageOps
import numpy as np

# %%
img_path='/home/mehedi/github/coursera/Introduction to Computer Vision and Image Processing/Week 2/Test_Image/'

# %%
img=Image.open(img_path+'baboon.jpg')

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img.format
# Out:
# 'JPEG'

# %%
img.size
# Out:
# (339, 509)

# %%
img.mode
# Out:
# 'RGB'

# %%
img.show(title='cat')

# %%
plt.imshow(img)

# %%
img_gray=ImageOps.grayscale(img)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img_gray.save(img_path+'baboon_gray.jpg')

# %%
img_gray.mode
# Out:
# 'L'

# %%
img_gray2=img_gray.quantize(2)

# %%
plt.imshow(img_gray2,cmap='gray')

# %%
red,green,blue=img.split()

# %%
plt.figure(figsize=(2.88*4,2.52*4))
plt.subplot(221)
plt.imshow(img,cmap='gray')

plt.subplot(222)
plt.imshow(red,cmap='gray')

plt.subplot(223)
plt.imshow(green,cmap='gray')

plt.subplot(224)
plt.imshow(blue,cmap='gray')

# %%
img_arr=np.array(img)
red_arr=np.array(red)
green_arr=np.array(green)
blue_arr=np.array(blue)

# %%
print(img_arr.shape)
print(red_arr.shape)
print(green_arr.shape)
print(blue_arr.shape)
# Out:
# (509, 339, 3)
# (509, 339)
# (509, 339)
# (509, 339)

# %%
img_red=img_arr.copy()
img_red[:,:,1]=0
img_red[:,:,2]=0

# %%
img_green=img_arr.copy()
img_green[:,:,0]=0
img_green[:,:,2]=0

# %%
img_blue=img_arr.copy()
img_blue[:,:,0]=0
img_blue[:,:,1]=0

# %%
plt.figure(figsize=(2.88*4,2.52*4))
plt.subplot(221)
plt.imshow(img_arr)

plt.subplot(222)
plt.imshow(img_red)

plt.subplot(223)
plt.imshow(img_green)

plt.subplot(224)
plt.imshow(img_blue)
